# %% [markdown]
# # Gaussian PDF and CDF

# %%
from scipy.stats import norm

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %%
norm.pdf(0, loc=5, scale=10)
# Out:
# 0.035206532676429952

# %%
import numpy as np

# %%
r = np.random.random(10)

# %%
norm.logpdf(r)
# Out:
# array([-0.93329088, -0.93403415, -0.9428647 , -0.98085856, -0.98460104,
#        -1.05240732, -1.1789345 , -0.93533043, -0.95050188, -1.07721109])

# %%
norm.cdf(r)
# Out:
# array([ 0.56726865,  0.5689715 ,  0.58657828,  0.6375468 ,  0.64146892,
#         0.69730325,  0.76457744,  0.57184092,  0.59918968,  0.71315433])

# %%
norm.logcdf(r)

# %%
r = np.random.randn(10000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(r, bins=100)
# Out:
# (array([   2.,    0.,    0.,    1.,    3.,    1.,    1.,    1.,    3.,
#            1.,    3.,    7.,   10.,   14.,   14.,   11.,   26.,   14.,
#           23.,   15.,   34.,   36.,   46.,   45.,   40.,   49.,   56.,
#           69.,   79.,   87.,   97.,   86.,  104.,  117.,  150.,  161.,
#          193.,  183.,  205.,  214.,  248.,  245.,  256.,  273.,  258.,
#          250.,  289.,  275.,  282.,  256.,  279.,  293.,  283.,  286.,
#          280.,  257.,  264.,  263.,  277.,  216.,  214.,  215.,  200.,
#          192.,  165.,  175.,  148.,  125.,  122.,  106.,  103.,   81.,
#           77.,   78.,   59.,   53.,   61.,   40.,   43.,   30.,   31.,
#           32.,   23.,   18.,   17.,   17.,    7.,    5.,    4.,    4.,
#            6.,    3.,    2.,    4.,    3.,    2.,    2.,    1.,    0.,    1.]),
#  array([-3.59324055, -3.52204288, -3.45084522, -3.37964755, -3.30844989,
#         -3.23725222, -3.16605456, -3.09485689, -3.02365923, -2.95246156,
#         -2.88126389, -2.81006623, -2.73886856, -2.6676709 , -2.59647323,
#         -2.52527557, -2.4540779 , -2.38288023, -2.31168257, -2.2404849 ,
#         -2.16928724, -2.09808957, -2.02689191, -1.95569424, -1.88449658,
#         -1.81329891, -1.74210124, -1.67090358, -1.59970591, -1.52850825,
#         -1.45731058, -1.38611292, -1.31491525, -1.24371758, -1.17251992,
#         -1.10132225, -1.03012459, -0.95892692, -0.88772926, -0.81653159,
#         -0.74533393, -0.67413626, -0.60293859, -0.53174093, -0.46054326,
#         -0.3893456 , -0.31814793, -0.24695027, -0.1757526 , -0.10455494,
#         -0.03335727,  0.0378404 ,  0.10903806,  0.18023573,  0.25143339,
#          0.32263106,  0.39382872,  0.46502639,  0.53622406,  0.60742172,
#          0.67861939,  0.74981705,  0.82101472,  0.89221238,  0.96341005,
#          1.03460771,  1.10580538,  1.17700305,  1.24820071,  1.31939838,
#          1.39059604,  1.46179371,  1.53299137,  1.60418904,  1.67538671,
#          1.74658437,  1.81778204,  1.8889797 ,  1.96017737,  2.03137503,
#          2.1025727 ,  2.17377036,  2.24496803,  2.3161657 ,  2.38736336,
#          2.45856103,  2.52975869,  2.60095636,  2.67215402,  2.74335169,
#          2.81454935,  2.88574702,  2.95694469,  3.02814235,  3.09934002,
#          3.17053768,  3.24173535,  3.31293301,  3.38413068,  3.45532835,
#          3.52652601]),
#  <a list of 100 Patch objects>)

# %%
r = 10*np.random.randn(10000)+5

# %%
plt.hist(r, bins=100)
# Out:
# (array([   6.,    3.,    4.,    4.,    4.,    5.,   10.,    9.,   10.,
#           12.,   10.,   20.,   20.,   18.,   24.,   29.,   33.,   35.,
#           38.,   33.,   51.,   62.,   61.,   66.,   85.,   91.,  106.,
#          106.,   97.,  114.,  119.,  136.,  156.,  168.,  157.,  196.,
#          202.,  207.,  212.,  218.,  227.,  208.,  266.,  243.,  241.,
#          250.,  288.,  282.,  279.,  245.,  245.,  258.,  245.,  239.,
#          256.,  231.,  238.,  233.,  230.,  212.,  187.,  175.,  153.,
#          150.,  122.,  157.,  128.,  105.,  119.,   96.,   84.,   93.,
#           68.,   67.,   59.,   64.,   52.,   47.,   26.,   47.,   25.,
#           12.,   18.,   15.,   13.,   12.,    7.,    9.,   11.,    2.,
#            7.,    2.,    4.,    3.,    0.,    2.,    2.,    2.,    0.,    2.]),
#  array([-26.58080036, -25.92372752, -25.26665467, -24.60958183,
#         -23.95250898, -23.29543614, -22.63836329, -21.98129045,
#         -21.3242176 , -20.66714476, -20.01007191, -19.35299907,
#         -18.69592622, -18.03885338, -17.38178054, -16.72470769,
#         -16.06763485, -15.410562  , -14.75348916, -14.09641631,
#         -13.43934347, -12.78227062, -12.12519778, -11.46812493,
#         -10.81105209, -10.15397924,  -9.4969064 ,  -8.83983355,
#          -8.18276071,  -7.52568787,  -6.86861502,  -6.21154218,
#          -5.55446933,  -4.89739649,  -4.24032364,  -3.5832508 ,
#          -2.92617795,  -2.26910511,  -1.61203226,  -0.95495942,
#          -0.29788657,   0.35918627,   1.01625911,   1.67333196,
#           2.3304048 ,   2.98747765,   3.64455049,   4.30162334,
#           4.95869618,   5.61576903,   6.27284187,   6.92991472,
#           7.58698756,   8.24406041,   8.90113325,   9.5582061 ,
#          10.21527894,  10.87235178,  11.52942463,  12.18649747,
#          12.84357032,  13.50064316,  14.15771601,  14.81478885,
#          15.4718617 ,  16.12893454,  16.78600739,  17.44308023,
#          18.10015308,  18.75722592,  19.41429877,  20.07137161,
#          20.72844445,  21.3855173 ,  22.04259014,  22.69966299,
#          23.35673583,  24.01380868,  24.67088152,  25.32795437,
#          25.98502721,  26.64210006,  27.2991729 ,  27.95624575,
#          28.61331859,  29.27039144,  29.92746428,  30.58453712,
#          31.24160997,  31.89868281,  32.55575566,  33.2128285 ,
#          33.86990135,  34.52697419,  35.18404704,  35.84111988,
#          36.49819273,  37.15526557,  37.81233842,  38.46941126,  39.12648411]),
#  <a list of 100 Patch objects>)

# %% [markdown]
# # Sampling from a Gaussian Distribution (Spherical and Axis-aligned Elliptical)

# %%
r = np.random.randn(10000, 2)

# %%
plt.scatter(r[:, 0], r[:, 1])

# %%
r[:, 1] = 5*r[:, 1] + 2

# %%
plt.scatter(r[:, 0], r[:, 1])

# %% [markdown]
# # Sampling from a General Multivariate Normal

# %%
cov = np.array([[1,0.8],[0.8,3]])

# %%
from scipy.stats import multivariate_normal as mvn

# %%
mu = np.array([0, 2])

# %%
r = mvn.rvs(mean=mu, cov=cov, size=1000)

# %%
plt.scatter(r[:, 0], r[:, 1])

# %%
r = np.random.multivariate_normal(mean=mu, cov=cov, size=1000)

# %%
plt.scatter(r[:, 0], r[:, 1])
